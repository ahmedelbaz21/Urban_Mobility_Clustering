# %% [markdown]
# # Phase 6: Deployment
#
# **CRISP-DM Phase Description:**
# The final phase involves organising and presenting the project findings so that the customer can use them, or integrating the model into a live production system. Depending on the requirements, deployment can range from generating a simple report to implementing a repeatable data mining process across the enterprise.
#
# ---

# %%
# Standard imports
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ---
# ### Task 1: Plan Deployment
#
# Develop a strategy for putting the data mining results to practical use. This includes:
#
# - **Deployment Strategy:** How will the model be consumed? Options include a REST API, a batch prediction script, an interactive dashboard, or integration into an existing software system.
# - **Infrastructure Requirements:** What technical environment is needed (e.g., cloud services, web server, containerisation)?
# - **Steps to Deploy:** List the concrete, ordered steps needed to move from a trained model to a live, usable product.
# - **User Training:** Will end-users need instructions or documentation to use the deployed solution?
#
# **Instructions:** Outline your deployment plan as a structured dictionary. If building an API or script, sketch the basic structure in code.

# %%
# TODO: Plan the deployment of your model/solution.

deployment_plan = {
    "strategy": "Batch Analytics + Interactive Dashboard",

    "infrastructure": [
        "Python (data processing pipeline)",
        "Jupyter Notebook / Python scripts",
        "Streamlit or Tableau for dashboard visualization",
        "Pandas for batch processing",
        "Matplotlib/Seaborn for spatial visualisation"
    ],

    "deployment_steps": [
        "Step 1: Save trained clustering model (K-Means) using joblib or pickle",
        "Step 2: Load new Uber trip data in batch mode",
        "Step 3: Apply preprocessing (feature engineering: Lat, Lon, time features)",
        "Step 4: Run clustering model to assign each trip to a demand zone",
        "Step 5: Visualise clusters on an interactive dashboard or map",
        "Step 6: Generate reports for high-demand zones to support decision making"
    ],

    "user_documentation": "A simple user guide will be provided explaining how to load new data and interpret cluster outputs in the dashboard",

    "target_audience": "City planners, Uber operations teams, and data analysts"
}

# %%
# Optional: Sketch a basic deployment script or API structure

# Example: Saving the trained model for deployment
# import joblib
# MODEL_PATH = 'path/to/your/saved_model.pkl'
# joblib.dump(best_model, MODEL_PATH)
# print(f"Model saved to: {MODEL_PATH}")

# Example: Basic prediction function skeleton
# def predict(input_data: dict) -> dict:
#     """
#     Takes a dictionary of feature values,
#     returns the model's prediction.
#     """
#     model = joblib.load(MODEL_PATH)
#     input_df = pd.DataFrame([input_data])
#     prediction = model.predict(input_df)
#     return {"prediction": prediction.tolist()}

# %%
# Display the deployment plan
print(json.dumps(deployment_plan, indent=2))
# Out:
# {
#   "strategy": "Batch Analytics + Interactive Dashboard",
#   "infrastructure": [
#     "Python (data processing pipeline)",
#     "Jupyter Notebook / Python scripts",
#     "Streamlit or Tableau for dashboard visualization",
#     "Pandas for batch processing",
#     "Matplotlib/Seaborn for spatial visualisation"
#   ],
#   "deployment_steps": [
#     "Step 1: Save trained clustering model (K-Means) using joblib or pickle",
#     "Step 2: Load new Uber trip data in batch mode",
#     "Step 3: Apply preprocessing (feature engineering: Lat, Lon, time features)",
#     "Step 4: Run clustering model to assign each trip to a demand zone",
#     "Step 5: Visualise clusters on an interactive dashboard or map",
#     "Step 6: Generate reports for high-demand zones to support decision making"
#   ],
#   "user_documentation": "A simple user guide will be provided explaining how to load new data and interpret cluster outputs in the dashboard",
#   "target_audience": "City planners, Uber operations teams, and data analysts"
# }

# %% [markdown]
# ---
# ### Task 2: Plan Monitoring and Maintenance
#
# A deployed model is not "set and forget". Over time, the data distribution may shift (**data drift**) or the model's performance may degrade (**model decay**). This task creates a monitoring and maintenance plan:
#
# - **Performance Monitoring:** How and how often will the model's predictions be evaluated against actuals?
# - **Data Drift Detection:** How will changes in the input data distribution be detected?
# - **Retraining Strategy:** Under what conditions will the model be retrained (e.g., scheduled, triggered by performance drop)?
# - **Logging and Alerting:** What will be logged, and what triggers an alert?
#
# **Instructions:** Document your monitoring and maintenance plan.

# %%
# TODO: Plan monitoring and maintenance.

monitoring_plan = {
    "performance_monitoring": {
        "frequency": "Monthly",
        "metrics_tracked": ["Silhouette Score", "Cluster Stability", "Inertia (K-Means)"],
        "method": "Compare clustering consistency on new ride data and re-evaluate cluster quality metrics"
    },

    "data_drift_detection": {
        "method": "Distribution comparison of latitude/longitude using statistical checks (e.g., KS test or visual drift analysis)",
        "frequency": "Monthly",
        "threshold": "Retrain if significant shift in spatial distribution or silhouette score drops below 0.3"
    },

    "retraining_strategy": {
        "trigger": "Scheduled quarterly OR when cluster quality significantly decreases",
        "data_source": "Latest Uber ride data (rolling 3–6 month window)",
        "responsible_team": "Data Science / Analytics Team"
    },

    "logging": {
        "what_to_log": [
            "Input coordinates (latitude, longitude)",
            "Cluster assignments",
            "Model version",
            "Evaluation metrics (silhouette score)"
        ],
        "alert_conditions": [
            "Drop in silhouette score below threshold",
            "Significant increase in noise points (DBSCAN)",
            "Sudden shift in spatial distribution"
        ]
    }
}

# %%
# Display the monitoring plan
print(json.dumps(monitoring_plan, indent=2))
# Out:
# {
#   "performance_monitoring": {
#     "frequency": "Monthly",
#     "metrics_tracked": [
#       "Silhouette Score",
#       "Cluster Stability",
#       "Inertia (K-Means)"
#     ],
#     "method": "Compare clustering consistency on new ride data and re-evaluate cluster quality metrics"
#   },
#   "data_drift_detection": {
#     "method": "Distribution comparison of latitude/longitude using statistical checks (e.g., KS test or visual drift analysis)",
#     "frequency": "Monthly",
#     "threshold": "Retrain if significant shift in spatial distribution or silhouette score drops below 0.3"
#   },
#   "retraining_strategy": {
#     "trigger": "Scheduled quarterly OR when cluster quality significantly decreases",
#     "data_source": "Latest Uber ride data (rolling 3\u20136 month window)",
#     "responsible_team": "Data Science / Analytics Team"
#   },
#   "logging": {
#     "what_to_log": [
#       "Input coordinates (latitude, longitude)",
#       "Cluster assignments",
#       "Model version",
#       "Evaluation metrics (silhouette score)"
#     ],
#     "alert_conditions": [
#       "Drop in silhouette score below threshold",
#       "Significant increase in noise points (DBSCAN)",
#       "Sudden shift in spatial distribution"
#     ]
#   }
# }

# %% [markdown]
# ---
# ### Task 3: Produce Final Report
#
# Compile a final summary of the entire project. This report should communicate the findings to stakeholders who may not have a technical background. It typically includes:
#
# - **Executive Summary:** A brief overview of the problem, approach, and key results.
# - **Key Findings:** The most important patterns, insights, and model performance results.
# - **Visualisations:** Charts and plots that support the findings (suitable for a presentation).
# - **Recommendations:** Actionable recommendations based on the analysis.
# - **Limitations:** Known limitations and caveats of the analysis.
#
# **Instructions:** Draft the final report content below. Include any code needed to generate summary visualisations.

# %%
# TODO: Draft the final report as a structured document.

final_report = {
    "title": "Urban Mobility Analysis: Clustering NYC Ride Demand Hotspots",

    "executive_summary": 
    "This project analyzes Uber pickup data in New York City to identify high-demand geographic hotspots using clustering techniques. By applying K-Means, Agglomerative Clustering, and DBSCAN, the study uncovers spatial patterns in ride demand to support improved driver allocation and urban mobility planning.",

    "key_findings": [
        "Ride demand is highly concentrated in specific urban hotspots within NYC.",
        "Agglomerative Clustering provided the most stable and meaningful cluster structure.",
        "K-Means effectively identified general spatial demand zones.",
        "DBSCAN performed poorly due to sensitivity to density variations and parameter tuning.",
        "Temporal and spatial features strongly influence ride distribution patterns."
    ],

    "model_performance": {
        "best_model": "Agglomerative Clustering",
        "key_metric": "Silhouette Score",
        "key_metric_value": 0.44
    },

    "recommendations": [
        "Allocate drivers dynamically to high-demand clusters to reduce waiting times.",
        "Focus operational resources on identified hotspot zones during peak hours.",
        "Integrate real-time data (traffic, weather) for improved demand prediction.",
        "Use clustering results to support urban planning and ride optimization strategies."
    ],

    "limitations": [
        "Dataset lacks external factors such as weather, traffic, and pricing.",
        "DBSCAN performance was limited by parameter sensitivity.",
        "Analysis is based on sampled data, which may not fully represent all ride patterns.",
        "Only spatial features were used for clustering, limiting model richness."
    ]
}

# %%
# Display the final report
print("=" * 60)
print(f"FINAL REPORT: {final_report['title']}")
print("=" * 60)

print(f"\n--- Executive Summary ---")
print(final_report['executive_summary'])

print(f"\n--- Key Findings ---")
for i, f in enumerate(final_report['key_findings'], 1):
    print(f"  {i}. {f}")

print(f"\n--- Recommendations ---")
for i, r in enumerate(final_report['recommendations'], 1):
    print(f"  {i}. {r}")

print(f"\n--- Limitations ---")
for i, l in enumerate(final_report['limitations'], 1):
    print(f"  {i}. {l}")
# Out:
# ============================================================
# FINAL REPORT: Urban Mobility Analysis: Clustering NYC Ride Demand Hotspots
# ============================================================
#
# --- Executive Summary ---
# This project analyzes Uber pickup data in New York City to identify high-demand geographic hotspots using clustering techniques. By applying K-Means, Agglomerative Clustering, and DBSCAN, the study uncovers spatial patterns in ride demand to support improved driver allocation and urban mobility planning.
#
# --- Key Findings ---
#   1. Ride demand is highly concentrated in specific urban hotspots within NYC.
#   2. Agglomerative Clustering provided the most stable and meaningful cluster structure.
#   3. K-Means effectively identified general spatial demand zones.
#   4. DBSCAN performed poorly due to sensitivity to density variations and parameter tuning.
#   5. Temporal and spatial features strongly influence ride distribution patterns.
#
# --- Recommendations ---
#   1. Allocate drivers dynamically to high-demand clusters to reduce waiting times.
#   2. Focus operational resources on identified hotspot zones during peak hours.
#   3. Integrate real-time data (traffic, weather) for improved demand prediction.
#   4. Use clustering results to support urban planning and ride optimization strategies.
#
# --- Limitations ---
#   1. Dataset lacks external factors such as weather, traffic, and pricing.
#   2. DBSCAN performance was limited by parameter sensitivity.
#   3. Analysis is based on sampled data, which may not fully represent all ride patterns.
#   4. Only spatial features were used for clustering, limiting model richness.

# %%
# Optional: Generate summary visualisations for the stakeholder presentation

import matplotlib.pyplot as plt

# Model names and real results from your Phase 4
models = ['K-Means', 'Agglomerative', 'DBSCAN']
scores = [0.3718, 0.4469, -0.3657]  

plt.figure(figsize=(8, 5))
plt.bar(models, scores, color=['#4C72B0', '#55A868', '#C44E52'], edgecolor='black')

plt.title('Clustering Model Performance Comparison', fontsize=14)
plt.ylabel('Silhouette Score')
plt.axhline(0, color='black', linewidth=0.8)

# value labels
for i, v in enumerate(scores):
    plt.text(i, v + 0.02 if v >= 0 else v - 0.05, f'{v:.2f}', ha='center', fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### Task 4: Review Project
#
# Conduct a project retrospective. Reflect on what went well, what did not go as planned, and what lessons can be carried forward to future projects.
#
# - **What went well?** Successes, effective techniques, good decisions.
# - **What could be improved?** Challenges, mistakes, or inefficiencies encountered.
# - **Lessons learned:** Key takeaways for future data science projects.
# - **Skills developed:** New skills or knowledge gained during the project.
#
# **Instructions:** Complete the project retrospective below.

# %%
# TODO: Conduct the project retrospective.

project_retrospective = {
    "went_well": [
        "Successfully identified clear spatial clusters of Uber demand using multiple clustering algorithms.",
        "Agglomerative Clustering produced strong and interpretable results.",
        "Effective use of geospatial features (latitude and longitude) enabled meaningful hotspot detection.",
        "Clear comparison of multiple models improved overall analysis quality."
    ],

    "could_improve": [
        "Limited feature set restricted model depth (no traffic, weather, or pricing data).",
        "DBSCAN required extensive parameter tuning and still underperformed.",
        "Notebook execution issues highlighted the need for better variable management.",
        "Computational limitations required sampling of the dataset."
    ],

    "lessons_learned": [
        "Always validate data structure before modeling to avoid runtime errors.",
        "Model performance depends heavily on data distribution and feature selection.",
        "Unsupervised learning requires careful interpretation rather than relying on a single metric.",
        "Visualisation is critical for interpreting clustering results effectively."
    ],

    "skills_developed": [
        "Geospatial data analysis using clustering techniques.",
        "Model evaluation using silhouette score and cluster interpretation.",
        "Data preprocessing and feature engineering for spatial datasets.",
        "Comparative analysis of unsupervised machine learning models."
    ]
}

# %%
# Display the retrospective
print("=" * 60)
print("PROJECT RETROSPECTIVE")
print("=" * 60)

sections = [
    ("What Went Well", project_retrospective['went_well']),
    ("What Could Be Improved", project_retrospective['could_improve']),
    ("Lessons Learned", project_retrospective['lessons_learned']),
    ("Skills Developed", project_retrospective['skills_developed']),
]
for section_name, items in sections:
   print(f"\n--- {section_name} ---")
if items:
    for item in items:
             print(f"  - {item}")
    else:
             print("  [Not yet documented]")
# Out:
# ============================================================
# PROJECT RETROSPECTIVE
# ============================================================
#
# --- What Went Well ---
#
# --- What Could Be Improved ---
#
# --- Lessons Learned ---
#
# --- Skills Developed ---
#   - Geospatial data analysis using clustering techniques.
#   - Model evaluation using silhouette score and cluster interpretation.
#   - Data preprocessing and feature engineering for spatial datasets.
#   - Comparative analysis of unsupervised machine learning models.
#   [Not yet documented]

# %% [markdown]
# ---
#
# ## Key Takeaway on Iteration
#
# While the six CRISP-DM phases are presented **sequentially** in these notebooks, in practice the process is **highly iterative**. Real-world data science projects rarely follow a straight line from Phase 1 to Phase 6.
#
# Common iteration patterns include:
#
# - **Modelling → Data Preparation:** If the model performs poorly, you may return to Phase 3 to engineer new features, clean data differently, or acquire more data.
# - **Evaluation → Modelling:** If the model does not meet the business success criteria, you may go back to Phase 4 to try different algorithms or tune hyperparameters.
# - **Deployment → Evaluation:** If the deployed model underperforms in production (data drift), you may return to Phase 5 to re-evaluate and then to Phase 3/4 to retrain.
# - **Any Phase → Business Understanding:** New findings in later phases may redefine the business objectives or success criteria originally set in Phase 1.
#
# ```
# ┌───────────────────────────────────────────────────────────┐
# │                     CRISP-DM Lifecycle                    │
# │                                                           │
# │   Phase 1 ──► Phase 2 ──► Phase 3 ──► Phase 4            │
# │   Business    Data        Data        Modelling           │
# │   Under.      Under.      Prep.           │               │
# │     ▲                       ▲              │               │
# │     │                       │              ▼               │
# │     │                       └──────── Phase 5             │
# │     │                                Evaluation           │
# │     │                                    │                │
# │     │                                    ▼                │
# │     └──────────────────────────────  Phase 6              │
# │                                     Deployment            │
# └───────────────────────────────────────────────────────────┘
# ```
#
# > **Remember:** Iteration is not failure — it is the *expected* workflow. Each cycle through the process deepens your understanding of both the data and the business problem, ultimately leading to a better solution.
